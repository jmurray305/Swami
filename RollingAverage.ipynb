# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
# df = pd.read_csv('./data/MASTER2010_2020.csv',index_col='Unnamed: 0')
df = pd.read_csv('./data/MASTER2002_2010.csv', index_col = 'Unnamed: 0')

# %%
df['HomeOrAway'] = df['HomeOrAway'].replace(np.nan, 'Home', regex=True)

# subsetDataFrame = df[df['Team_Name'] == 'Indianapolis Colts']
# subsetDataFrame

# %%
def teamTotalsStats(s):
    if s['HomeOrAway'] == 'Home':
         return s['Home_TotYd']
    else:
        return s['Away_TotYd']
    
def teamQBcomp(s):
    if s['HomeOrAway'] == 'Home':
         return s['Home_QB_Passing_Cmp']
    else:
        return s['Away_QB_Passing_Cmp']
    
def teamQBAtt(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_QB_Passing_Att']
    else:
        return s['Away_QB_Passing_Att']
    
def teamQBPass_Yds(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_QB_Passing_Yds']
    else:
        return s['Away_QB_Passing_Yds']   

def teamQBPass_TD(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_QB_Passing_TD']
    else:
        return s['Away_QB_Passing_TD']   

def teamQBPass_INT(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_QB_Passing_Int']
    else:
        return s['Away_QB_Passing_Int']

def teamQBPass_TD(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_QB_Passing_TD']
    else:
        return s['Away_QB_Passing_TD'] 

def teamQBPass_Long(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_QB_Passing_Lng']
    else:
        return s['Away_QB_Passing_Lng'] 
    
def teamQBPass_Rate(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_QB_Passing_Rate']
    else:
        return s['Away_QB_Passing_Rate'] 
    
def teamRB1_Rush_Yds(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_RB1_Rushing_Yds']
    else:
        return s['A_RB1_Rushing_Yds'] 
      
def teamRB1_Lng(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_RB1_Rushing_Lng']
    else:
        return s['A_RB1_Rushing_Lng'] 
    
def teamRB1_TD(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_RB1_Receiving_TD']
    else:
        return s['A_RB1_Receiving_TD'] 
    
def teamWR1_Tgt(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_WR1_Receiving_Tgt']
    else:
        return s['A_WR1_Receiving_Tgt'] 
    
def teamWR1_Rec(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_WR1_Receiving_Rec']
    else:
        return s['H_WR1_Receiving_Rec'] 
    
def teamWR1_Yrds(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_WR1_Receiving_Yds']
    else:
        return s['A_WR1_Receiving_Yds'] 
    
def teamWR1_TDs(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_WR1_Rushing_TD']
    else:
        return s['A_WR1_Rushing_TD'] 
    
def teamWR2_Tgt(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_WR2_Receiving_Tgt']
    else:
        return s['A_WR2_Receiving_Tgt'] 
    
def teamWR2_Rec(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_WR2_Receiving_Rec']
    else:
        return s['H_WR2_Receiving_Rec'] 
    
def teamWR2_Yrds(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_WR2_Receiving_Yds']
    else:
        return s['A_WR2_Receiving_Yds'] 
    
def teamWR2_TDs(s):
    if s['HomeOrAway'] == 'Home':
        return s['H_WR2_Rushing_TD']
    else:
        return s['A_WR2_Rushing_TD'] 

def team1stDown(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_First_Downs']
    else:
        return s['Away_First_Downs'] 
    
def team3rdDown(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_Third_Down_Conv']
    else:
        return s['Away_Third_Down_Conv'] 
    
def teamTimePoss(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_Time_of_Possession']
    else:
        return s['Away_Time_of_Possession'] 

def teamPenalties(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_Penalties']
    else:
        return s['Away_Penalties'] 

def teamPenaltiesYrd(s):
    if s['HomeOrAway'] == 'Home':
        return s['Home_Penalties_Yd']
    else:
        return s['Away_Penalties_Yd']

# %%
def oppTotalsStats(s):
    if s['HomeOrAway'] != 'Home':
         return s['Away_TotYd']
    else:
        return s['Home_TotYd']
    
def oppQBcomp(s):
    if s['HomeOrAway'] != 'Home':
         return s['Away_QB_Passing_Cmp']
    else:
        return s['Home_QB_Passing_Cmp']
    
def oppQBAtt(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_QB_Passing_Att']
    else:
        return s['Home_QB_Passing_Att']
    
def oppQBPass_Yds(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_QB_Passing_Yds']
    else:
        return s['Home_QB_Passing_Yds']  

def oppQBPass_TD(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_QB_Passing_TD']  
    else:
        return s['Home_QB_Passing_TD']  

def oppQBPass_INT(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_QB_Passing_Int']
    else:
        return s['Home_QB_Passing_Int']

def oppQBPass_TD(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_QB_Passing_TD']
    else:
        return s['Home_QB_Passing_TD']

def oppQBPass_Long(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_QB_Passing_Lng'] 
    else:
        return s['Home_QB_Passing_Lng']
    
def oppQBPass_Rate(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_QB_Passing_Rate']
    else:
        return s['Home_QB_Passing_Rate']
    
def oppRB1_Rush_Yds(s):
    if s['HomeOrAway'] != 'Home':
        return s['A_RB1_Rushing_Yds']
    else:
        return s['H_RB1_Rushing_Yds']
      
def oppRB1_Lng(s):
    if s['HomeOrAway'] != 'Home':
        return s['A_RB1_Rushing_Lng'] 
    else:
        return s['H_RB1_Rushing_Lng']
    
def oppRB1_TD(s):
    if s['HomeOrAway'] != 'Home':
        return s['A_RB1_Receiving_TD']
    else:
        return s['H_RB1_Receiving_TD']
    
def oppWR1_Tgt(s):
    if s['HomeOrAway'] != 'Home':
        return s['A_WR1_Receiving_Tgt'] 
    else:
        return s['H_WR1_Receiving_Tgt']
    
def oppWR1_Rec(s):
    if s['HomeOrAway'] != 'Home':
        return s['H_WR1_Receiving_Rec']
    else:
        return s['H_WR1_Receiving_Rec']
    
def oppWR1_Yrds(s):
    if s['HomeOrAway'] != 'Home':
        return s['A_WR1_Receiving_Yds'] 
    else:
        return s['H_WR1_Receiving_Yds']
    
def oppWR1_TDs(s):
    if s['HomeOrAway'] != 'Home':
        return s['A_WR1_Rushing_TD'] 
    else:
        return s['H_WR1_Rushing_TD'] 
    
def oppWR2_Tgt(s):
    if s['HomeOrAway'] != 'Home':
        return s['A_WR2_Receiving_Tgt'] 
    else:
        return s['H_WR2_Receiving_Tgt']
    
def oppWR2_Rec(s):
    if s['HomeOrAway'] != 'Home':
        return s['H_WR2_Receiving_Rec']
    else:
        return s['H_WR2_Receiving_Rec']
    
def oppWR2_Yrds(s):
    if s['HomeOrAway'] != 'Home':
        return s['A_WR2_Receiving_Yds']
    else:
        return s['H_WR2_Receiving_Yds']
    
def oppWR2_TDs(s):
    if s['HomeOrAway'] != 'Home':
        return s['A_WR2_Rushing_TD']
    else:
        return s['H_WR2_Rushing_TD']

def opp1stDown(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_First_Downs'] 
    else:
        return s['Home_First_Downs'] 
    
def opp3rdDown(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_Third_Down_Conv'] 
    else:
        return s['Home_Third_Down_Conv'] 
    
def oppTimePoss(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_Time_of_Possession']
    else:
        return s['Home_Time_of_Possession']

def oppPenalties(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_Penalties']
    else:
        return s['Home_Penalties']

def oppPenaltiesYrd(s):
    if s['HomeOrAway'] != 'Home':
        return s['Away_Penalties_Yd'] 
    else:
        return s['Home_Penalties_Yd']

# %%
teamnames = df['Team_Name'].value_counts().keys()

# %%
ROLLING_MEAN1 = pd.DataFrame()
for x in range(2002,2010):
    yeardf = pd.DataFrame()
    for i in teamnames:
        try:
            rolltemp = pd.DataFrame()
            roll = pd.DataFrame()
            subyear = df[df['Team_Year'] == x ]
            subteam = subyear[subyear['Team_Name'] == i]
            subteam = subteam.sort_values(by=['Date_y'])
            subteam = subteam[subteam['Week'].notna()]
            subteam.drop_duplicates(inplace=True)
            subteam = subteam.reset_index(drop=True)
            roll['oppTotalYrds'] = subteam.apply(lambda row: oppTotalsStats(row), axis=1)
            rolltemp['temp'] = roll['oppTotalYrds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppTotalYardsRoll'] = rolltemp.iloc[:,-1]
            roll['oppQBcomp'] = subteam.apply(lambda row: oppQBcomp(row), axis = 1)
            rolltemp['temp'] = roll['oppQBcomp']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppBcompRoll'] = rolltemp.iloc[:,-1]
            roll['oppQBAtt'] = subteam.apply(lambda row: oppQBAtt(row), axis = 1)
            rolltemp['temp'] = roll['oppQBAtt']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppQBAttRoll'] = rolltemp.iloc[:,-1]
            roll['oppQBPass_Yds'] = subteam.apply(lambda row: oppQBPass_Yds(row), axis = 1)
            rolltemp['temp'] = roll['oppQBPass_Yds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppQBPass_YdsRoll'] = rolltemp.iloc[:,-1]
            roll['oppQBPass_TD'] = subteam.apply(lambda row: oppQBPass_TD(row), axis = 1)
            rolltemp['temp'] = roll['oppQBPass_TD']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppQBPass_TDRoll'] = rolltemp.iloc[:,-1]
            roll['oppQBPass_INT'] = subteam.apply(lambda row: oppQBPass_INT(row), axis = 1)
            rolltemp['temp'] = roll['oppQBPass_INT']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppQBPass_INTRoll'] = rolltemp.iloc[:,-1]
            roll['oppQBPass_TD'] = subteam.apply(lambda row: oppQBPass_TD(row), axis = 1)
            rolltemp['temp'] = roll['oppQBPass_TD']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppQBPass_TDRoll'] = rolltemp.iloc[:,-1]
            roll['oppQBPass_Long'] = subteam.apply(lambda row: oppQBPass_Long(row), axis = 1)
            rolltemp['temp'] = roll['oppQBPass_Long']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppQBPass_LongRoll'] = rolltemp.iloc[:,-1]
            roll['oppQBPass_Rate'] = subteam.apply(lambda row: oppQBPass_Rate(row), axis = 1)
            rolltemp['temp'] = roll['oppQBPass_Rate']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppQBPass_RateRoll'] = rolltemp.iloc[:,-1]
            roll['oppRB1_Rush_Yds'] = subteam.apply(lambda row: oppRB1_Rush_Yds(row), axis = 1)
            rolltemp['temp'] = roll['oppRB1_Rush_Yds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppRB1_Rush_YdsRoll'] = rolltemp.iloc[:,-1]
            roll['oppRB1_Lng'] = subteam.apply(lambda row: oppRB1_Lng(row), axis = 1)
            rolltemp['temp'] = roll['oppRB1_Lng']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppRB1_LngRoll'] = rolltemp.iloc[:,-1]
            roll['oppWR1_Tgt'] = subteam.apply(lambda row: oppWR1_Tgt(row), axis = 1)
            rolltemp['temp'] = roll['oppWR1_Tgt']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppWR1_TgtRoll'] = rolltemp.iloc[:,-1]
            roll['oppWR1_Rec'] = subteam.apply(lambda row: oppWR1_Rec(row), axis = 1)
            rolltemp['temp'] = roll['oppWR1_Rec']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppWR1_RecRoll'] = rolltemp.iloc[:,-1]
            roll['oppWR1_Yrds'] = subteam.apply(lambda row: oppWR1_Yrds(row), axis = 1)
            rolltemp['temp'] = roll['oppWR1_Yrds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppWR1_YrdsRoll'] = rolltemp.iloc[:,-1]
            roll['oppWR1_TDs'] = subteam.apply(lambda row: oppWR1_TDs(row), axis = 1)
            rolltemp['temp'] = roll['oppWR1_TDs']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppWR1_TDsRoll'] = rolltemp.iloc[:,-1]
            roll['oppWR2_Tgt'] = subteam.apply(lambda row: oppWR2_Tgt(row), axis = 1)
            rolltemp['temp'] = roll['oppWR2_Tgt']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppWR2_TgtRoll'] = rolltemp.iloc[:,-1]
            roll['oppWR2_Yrds'] = subteam.apply(lambda row: oppWR2_Yrds(row), axis = 1)
            rolltemp['temp'] = roll['oppWR2_Yrds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppWR2_YrdsRoll'] = rolltemp.iloc[:,-1]
            roll['oppWR2_TDs'] = subteam.apply(lambda row: oppWR2_TDs(row), axis = 1)
            rolltemp['temp'] = roll['oppWR2_TDs']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppWR2_TDsRoll'] = rolltemp.iloc[:,-1]
            roll['opp1stDown'] = subteam.apply(lambda row: opp1stDown(row), axis = 1)
            rolltemp['temp'] = roll['opp1stDown']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['opp1stDownRoll'] = rolltemp.iloc[:,-1]
            roll['opp3rdDown'] = subteam.apply(lambda row: opp3rdDown(row), axis = 1)
            rolltemp['temp'] = roll['opp3rdDown']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['opp3rdDownRoll'] = rolltemp.iloc[:,-1]
            roll['oppTimePoss'] = subteam.apply(lambda row: oppTimePoss(row), axis = 1)
            rolltemp['temp'] = roll['oppTimePoss']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppTimePossRoll'] = rolltemp.iloc[:,-1]
            roll['oppPenalties'] = subteam.apply(lambda row: oppPenalties(row), axis = 1)
            rolltemp['temp'] = roll['oppPenalties']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppPenaltiesRoll'] = rolltemp.iloc[:,-1]
            roll['oppPenaltiesYrd'] = subteam.apply(lambda row: oppPenaltiesYrd(row), axis = 1)
            rolltemp['temp'] = roll['oppPenaltiesYrd']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['oppPenaltiesYrdRoll'] = rolltemp.iloc[:,-1]
            roll['teamTotalYrds'] = subteam.apply(lambda row: teamTotalsStats(row), axis=1)
            rolltemp['temp'] = roll['teamTotalYrds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['TeamTotalYardsRoll'] = rolltemp.iloc[:,-1]
            roll['teamQBcomp'] = subteam.apply(lambda row: teamQBcomp(row), axis = 1)
            rolltemp['temp'] = roll['teamQBcomp']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamQBcompRoll'] = rolltemp.iloc[:,-1]
            roll['teamQBAtt'] = subteam.apply(lambda row: teamQBAtt(row), axis = 1)
            rolltemp['temp'] = roll['teamQBAtt']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamQBAttRoll'] = rolltemp.iloc[:,-1]
            roll['teamQBPass_Yds'] = subteam.apply(lambda row: teamQBPass_Yds(row), axis = 1)
            rolltemp['temp'] = roll['teamQBPass_Yds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamQBPass_YdsRoll'] = rolltemp.iloc[:,-1]
            roll['teamQBPass_TD'] = subteam.apply(lambda row: teamQBPass_TD(row), axis = 1)
            rolltemp['temp'] = roll['teamQBPass_TD']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamQBPass_TDRoll'] = rolltemp.iloc[:,-1]
            roll['teamQBPass_INT'] = subteam.apply(lambda row: teamQBPass_INT(row), axis = 1)
            rolltemp['temp'] = roll['teamQBPass_INT']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamQBPass_INTRoll'] = rolltemp.iloc[:,-1]
            roll['teamQBPass_TD'] = subteam.apply(lambda row: teamQBPass_TD(row), axis = 1)
            rolltemp['temp'] = roll['teamQBPass_TD']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamQBPass_TDRoll'] = rolltemp.iloc[:,-1]
            roll['teamQBPass_Long'] = subteam.apply(lambda row: teamQBPass_Long(row), axis = 1)
            rolltemp['temp'] = roll['teamQBPass_Long']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamQBPass_LongRoll'] = rolltemp.iloc[:,-1]
            roll['teamQBPass_Rate'] = subteam.apply(lambda row: teamQBPass_Rate(row), axis = 1)
            rolltemp['temp'] = roll['teamQBPass_Rate']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamQBPass_RateRoll'] = rolltemp.iloc[:,-1]
            roll['teamRB1_Rush_Yds'] = subteam.apply(lambda row: teamRB1_Rush_Yds(row), axis = 1)
            rolltemp['temp'] = roll['teamRB1_Rush_Yds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamRB1_Rush_YdsRoll'] = rolltemp.iloc[:,-1]
            roll['teamRB1_Lng'] = subteam.apply(lambda row: teamRB1_Lng(row), axis = 1)
            rolltemp['temp'] = roll['teamRB1_Lng']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamRB1_LngRoll'] = rolltemp.iloc[:,-1]
            roll['teamWR1_Tgt'] = subteam.apply(lambda row: teamWR1_Tgt(row), axis = 1)
            rolltemp['temp'] = roll['teamWR1_Tgt']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamWR1_TgtRoll'] = rolltemp.iloc[:,-1]
            roll['teamWR1_Rec'] = subteam.apply(lambda row: teamWR1_Rec(row), axis = 1)
            rolltemp['temp'] = roll['teamWR1_Rec']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamWR1_RecRoll'] = rolltemp.iloc[:,-1]
            roll['teamWR1_Yrds'] = subteam.apply(lambda row: teamWR1_Yrds(row), axis = 1)
            rolltemp['temp'] = roll['teamWR1_Yrds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamWR1_YrdsRoll'] = rolltemp.iloc[:,-1]
            roll['teamWR1_TDs'] = subteam.apply(lambda row: teamWR1_TDs(row), axis = 1)
            rolltemp['temp'] = roll['teamWR1_TDs']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamWR1_TDsRoll'] = rolltemp.iloc[:,-1]
            roll['teamWR2_Tgt'] = subteam.apply(lambda row: teamWR2_Tgt(row), axis = 1)
            rolltemp['temp'] = roll['teamWR2_Tgt']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamWR2_TgtRoll'] = rolltemp.iloc[:,-1]
            roll['teamWR2_Yrds'] = subteam.apply(lambda row: teamWR2_Yrds(row), axis = 1)
            rolltemp['temp'] = roll['teamWR2_Yrds']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamWR2_YrdsRoll'] = rolltemp.iloc[:,-1]
            roll['teamWR2_TDs'] = subteam.apply(lambda row: teamWR2_TDs(row), axis = 1)
            rolltemp['temp'] = roll['teamWR2_TDs']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamWR2_TDsRoll'] = rolltemp.iloc[:,-1]
            roll['team1stDown'] = subteam.apply(lambda row: team1stDown(row), axis = 1)
            rolltemp['temp'] = roll['team1stDown']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['team1stDownRoll'] = rolltemp.iloc[:,-1]
            roll['team3rdDown'] = subteam.apply(lambda row: team3rdDown(row), axis = 1)
            rolltemp['temp'] = roll['team3rdDown']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['team3rdDownRoll'] = rolltemp.iloc[:,-1]
            roll['teamTimePoss'] = subteam.apply(lambda row: teamTimePoss(row), axis = 1)
            rolltemp['temp'] = roll['teamTimePoss']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamTimePossRoll'] = rolltemp.iloc[:,-1]
            roll['teamPenalties'] = subteam.apply(lambda row: teamPenalties(row), axis = 1)
            rolltemp['temp'] = roll['teamPenalties']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamPenaltiesRoll'] = rolltemp.iloc[:,-1]
            roll['teamPenaltiesYrd'] = subteam.apply(lambda row: teamPenaltiesYrd(row), axis = 1)
            rolltemp['temp'] = roll['teamPenaltiesYrd']
            rolltemp['temp2'] = rolltemp.expanding(min_periods=4).mean()
            subteam['teamPenaltiesYrdRoll'] = rolltemp.iloc[:,-1]
            yeardf = yeardf.append(subteam, ignore_index=True, sort = False)
        except ValueError:
            pass
    ROLLING_MEAN1 = ROLLING_MEAN1.append(yeardf, ignore_index=True, sort = False)

# %%
#Dropping Ties and converting W and Ls to 1 and 0s
ROLLING_MEAN1 = ROLLING_MEAN1[~ROLLING_MEAN1.W_L.str.contains('T')]
wl_dict = {'W':1, 'L': 0}
ROLLING_MEAN1.replace({"W_L": wl_dict},inplace = True)

# %%
rdf_Cols = ['Week','W_L','OT','Home_Record','HomeOrAway','Opp','Expected Points_Home',
            'Expected Points_Away','Expected Points_Sp. Tms','Team_Name','Team_Year',
            'Home_QB_Player','Away_QB_Player','H_RB1_Player','H_RB2_Player','A_RB1_Player',
            'A_RB2_Player','H_WR1_Player','H_WR2_Player','H_WR3_Player','A_WR1_Player','A_WR2_Player',
            'A_WR3_Player','Roof','Surface','Duration','Attendance','Vegas Line','Over/Under','TeamTotalYardsRoll',
            'teamQBcompRoll','teamQBAttRoll','teamQBPass_YdsRoll','teamQBPass_TDRoll','teamQBPass_INTRoll',
            'teamQBPass_LongRoll','teamQBPass_RateRoll','teamRB1_Rush_YdsRoll','teamRB1_LngRoll','teamWR1_TgtRoll',
            'teamWR1_RecRoll','teamWR1_YrdsRoll','teamWR1_TDsRoll','teamWR2_TgtRoll','teamWR2_YrdsRoll',
            'teamWR2_TDsRoll','team1stDownRoll','team3rdDownRoll','teamTimePossRoll','teamPenaltiesRoll',
            'teamPenaltiesYrdRoll']
rollingOnlyCols = ['Week','W_L','HomeOrAway','Opp','Team_Name','Team_Year','TeamTotalYardsRoll',
            'teamQBcompRoll','teamQBAttRoll','teamQBPass_YdsRoll','teamQBPass_TDRoll','teamQBPass_INTRoll',
            'teamQBPass_LongRoll','teamQBPass_RateRoll','teamRB1_Rush_YdsRoll','teamRB1_LngRoll','teamWR1_TgtRoll',
            'teamWR1_RecRoll','teamWR1_YrdsRoll','teamWR1_TDsRoll','teamWR2_TgtRoll','teamWR2_YrdsRoll',
            'teamWR2_TDsRoll','team1stDownRoll','team3rdDownRoll','teamTimePossRoll','teamPenaltiesRoll',
            'teamPenaltiesYrdRoll']
rolling = ROLLING_MEAN1[rdf_Cols]
rollingOnly = rolling[rollingOnlyCols]

# %%
rollingHome = rolling[~rolling.HomeOrAway.str.contains('@')]
rollingColumnsAtHome = rollingOnly[~rollingOnly.HomeOrAway.str.contains('@')]

# %%
rolling.to_csv(r'./data/RollingAvg2002_2010.csv', encoding='utf-8', header='true')
rollingHome.to_csv(r'./data/HomeRollingAvg2002_2010.csv', encoding='utf-8', header='true')
rollingColumnsAtHome.to_csv(r'./data/RollingAvgOnly2002_2010.csv', encoding='utf-8', header='true')

# %%
rollingColumnsAtHome
# Out:
#      Week  W_L HomeOrAway                   Opp             Team_Name  \
# 0       1    1       Home   Pittsburgh Steelers  New England Patriots
# 1       3    1       Home  Jacksonville Jaguars  New England Patriots
# 4       7    1       Home         New York Jets  New England Patriots
# 5       8    1       Home        Miami Dolphins  New England Patriots
# 6       9    1       Home   Washington Redskins  New England Patriots
# ...   ...  ...        ...                   ...                   ...
# 2288    7    0       Home      Baltimore Ravens      Seattle Seahawks
# 2290    9    1       Home  Tampa Bay Buccaneers      Seattle Seahawks
# 2293   13    1       Home     Minnesota Vikings      Seattle Seahawks
# 2296   16    0       Home     Arizona Cardinals      Seattle Seahawks
# 2297   17    0       Home   San Francisco 49ers      Seattle Seahawks
#
#       Team_Year  TeamTotalYardsRoll  teamQBcompRoll  teamQBAttRoll  \
# 0          2015                 NaN             NaN            NaN
# 1          2015                 NaN             NaN            NaN
# 4          2015          376.600000       26.800000      41.000000
# 5          2015          386.666667       27.333333      42.500000
# 6          2015          397.142857       28.285714      44.142857
# ...         ...                 ...             ...            ...
# 2288       2019          364.833333       20.666667      29.333333
# 2290       2019          398.875000       20.875000      31.250000
# 2293       2019          389.181818       21.272727      32.727273
# 2296       2019          383.857143       20.785714      32.428571
# 2297       2019          381.466667       21.066667      33.000000
#
#       teamQBPass_YdsRoll  teamQBPass_TDRoll  teamQBPass_INTRoll  \
# 0                    NaN                NaN                 NaN
# 1                    NaN                NaN                 NaN
# 4             297.000000           2.200000            0.400000
# 5             299.500000           2.333333            0.333333
# 6             307.428571           2.285714            0.285714
# ...                  ...                ...                 ...
# 2288          260.000000           1.666667            0.000000
# 2290          262.000000           1.625000            0.125000
# 2293          260.090909           1.636364            0.181818
# 2296          259.285714           1.642857            0.428571
# 2297          260.466667           1.600000            0.600000
#
#       teamQBPass_LongRoll  teamQBPass_RateRoll  teamRB1_Rush_YdsRoll  \
# 0                     NaN                  NaN                   NaN
# 1                     NaN                  NaN                   NaN
# 4               42.800000           100.560000             44.000000
# 5               40.166667           100.150000             49.666667
# 6               38.285714            99.314286             43.142857
# ...                   ...                  ...                   ...
# 2288            38.833333           117.400000             69.166667
# 2290            38.875000           110.900000             75.500000
# 2293            35.363636           108.090909             72.818182
# 2296            37.000000           103.342857             74.142857
# 2297            36.000000           100.366667             75.000000
#
#       teamRB1_LngRoll  teamWR1_TgtRoll  teamWR1_RecRoll  teamWR1_YrdsRoll  \
# 0                 NaN              NaN              NaN               NaN
# 1                 NaN              NaN              NaN               NaN
# 4           11.200000        11.400000         6.600000         80.800000
# 5           13.166667        11.000000         6.500000         79.666667
# 6           11.714286        11.714286         7.142857         83.714286
# ...               ...              ...              ...               ...
# 2288        15.833333         6.000000         4.333333         67.500000
# 2290        16.125000         5.875000         4.375000         66.750000
# 2293        16.818182         6.454545         5.363636         66.363636
# 2296        19.642857         6.142857         5.785714         59.357143
# 2297        19.333333         6.200000         5.733333         57.466667
#
#       teamWR1_TDsRoll  teamWR2_TgtRoll  teamWR2_YrdsRoll  teamWR2_TDsRoll  \
# 0                 NaN              NaN               NaN              NaN
# 1                 NaN              NaN               NaN              NaN
# 4                 0.0         6.600000         61.400000              0.0
# 5                 0.0         7.333333         62.666667              0.0
# 6                 0.0         7.571429         66.000000              0.0
# ...               ...              ...               ...              ...
# 2288              0.0         4.000000         47.833333              0.0
# 2290              0.0         4.750000         51.875000              0.0
# 2293              0.0         6.181818         67.000000              0.0
# 2296              0.0         5.785714         66.500000              0.0
# 2297              0.0         6.200000         69.600000              0.0
#
#       team1stDownRoll  team3rdDownRoll  teamTimePossRoll  teamPenaltiesRoll  \
# 0                 NaN              NaN               NaN                NaN
# 1                 NaN              NaN               NaN                NaN
# 4           21.600000        44.441558               NaN           7.600000
# 5           22.000000        44.326299               NaN           8.166667
# 6           21.714286        45.136827         45.578444           7.571429
# ...               ...              ...               ...                ...
# 2288        21.166667        33.275613               NaN           6.666667
# 2290        22.000000        38.078882         34.562802           6.500000
# 2293        22.181818        38.256503         35.838033           6.909091
# 2296        21.500000        40.027284         36.703681           6.714286
# 2297        21.933333        40.389101         37.010800           6.400000
#
#       teamPenaltiesYrdRoll
# 0                      NaN
# 1                      NaN
# 4                74.200000
# 5                79.000000
# 6                73.142857
# ...                    ...
# 2288             51.666667
# 2290             49.125000
# 2293             52.272727
# 2296             51.071429
# 2297             48.666667
#
# [1150 rows x 28 columns]
